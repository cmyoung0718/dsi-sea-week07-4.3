# %% [markdown]
# ## Lab 4.3.

# %% [markdown]
# #### Setup your imports

# %%
import pandas as pd 
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_selection import f_classif, SelectKBest, VarianceThreshold
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1. Pull the training set from the newsgroup data
# The data has 20 different categories. Try to shrink down to smaller number of groups according to the definition here:
# http://scikit-learn.org/stable/datasets/twenty_newsgroups.html

# %%
newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
newsgroups_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'))
full = fetch_20newsgroups(remove=('headers', 'footers', 'quotes'))

# %%
y = newsgroups_train.target
x = newsgroups_train.data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
# Combine classes into 7
mappy = {
    0: [0],
    1: [1,2,3,4,5],
    2: [6],
    3: [7,8,9,10],
    4: [11,12,13,14],
    5: [15],
    6: [16,17,18,19]
}
def getkey(num):
    for x, y in mappy.items():
        if num in y:
            return x
y_train_new = [getkey(num) for num in y_train]
y_train = y_train_new
labels = ['alt','comp','misc','rec','sci','soc','talk']
print labels
# Out:
# ['alt', 'comp', 'misc', 'rec', 'sci', 'soc', 'talk']

# %%
mappy = {
    0: [0],
    1: [1,2,3,4,5],
    2: [6],
    3: [7,8,9,10],
    4: [11,12,13,14],
    5: [15],
    6: [16,17,18,19]
}
def getkey(num):
    for x, y in mappy.items():
        if num in y:
            return x
y_test_new = [getkey(num) for num in y_test]
y_test = y_test_new
labels = ['alt','comp','misc','rec','sci','soc','talk']
print labels
# Out:
# ['alt', 'comp', 'misc', 'rec', 'sci', 'soc', 'talk']

# %% [markdown]
# #### 2. Create the vectorizer

# %%
v = TfidfVectorizer(
stop_words='english',token_pattern='[a-zA-Z]{3,50}',ngram_range=(1,2), max_features=1000
)

# %%
pd.DataFrame(x)[0][1]
# Out:
# u"A fair number of brave souls who upgraded their SI clock oscillator have\nshared their experiences for this poll. Please send a brief message detailing\nyour experiences with the procedure. Top speed attained, CPU rated speed,\nadd on cards and adapters, heat sinks, hour of usage per day, floppy disk\nfunctionality with 800 and 1.4 m floppies are especially requested.\n\nI will be summarizing in the next two days, so please add to the network\nknowledge base if you have done the clock upgrade and haven't answered this\npoll. Thanks."

# %%
vec = v.fit(x)
x_train = vec.transform(x_train)

x_test = vec.transform(x_test)

# %% [markdown]
# What are top 50 most powerful terms in deciding news groups? (hint: treat it as a classification problem)?

# %%
X_train_dense = x_train.todense()
X_test_dense = x_test.todense()
scaler = StandardScaler()
s = scaler.fit(X_train_dense)
X_scld_train = s.transform(X_train_dense)
X_scld_test = s.transform(X_test_dense)

lr = LogisticRegression(multi_class='multinomial', solver='sag')
lr.fit(X_scld_train, y_train)
lr.coef_[:50]
# Out:
# array([[-0.00936865, -0.01388506,  0.04013826, ...,  0.03304059,
#         -0.02416485,  0.04847579],
#        [-0.02737374,  0.13684096, -0.03927782, ...,  0.06677219,
#         -0.08414736, -0.09027015],
#        [-0.07090089, -0.21079613, -0.10128567, ..., -0.14955889,
#         -0.0089506 ,  0.00239462],
#        ...,
#        [ 0.02826078,  0.09218857, -0.0131521 , ...,  0.09456123,
#          0.02394877, -0.02288088],
#        [ 0.02157911,  0.07011844,  0.09171377, ..., -0.08120347,
#          0.04453686,  0.04634855],
#        [-0.1158192 ,  0.00429873,  0.03472708, ..., -0.0005455 ,
#          0.04039196, -0.01127874]])

# %%
coefs
# Out:
#         fit    ground     learn      runs     night    person   similar  \
# 0  0.001080 -0.003157  0.019840 -0.006265  0.070955 -0.008398  0.044716
# 1 -0.007578  0.072241  0.011323  0.072061 -0.024619 -0.017709 -0.065234
# 2 -0.004223 -0.042286 -0.025942  0.011373 -0.014985  0.049335  0.019392
# 3  0.018378 -0.021222 -0.045684 -0.039922 -0.014920 -0.007206 -0.046665
# 4  0.006062  0.030207 -0.073128  0.005445 -0.031003 -0.074691  0.003089
# 5  0.023082  0.011929  0.096666 -0.002825 -0.008099  0.046225  0.011059
# 6 -0.036800 -0.047712  0.016924 -0.039868  0.022671  0.012444  0.033643
#
#        room    wonder     teams    ...       allows    market  probably  \
# 0  0.022340 -0.001396  0.006814    ...     0.044660  0.028512  0.066825
# 1 -0.019018 -0.011460  0.001673    ...     0.042555  0.022798 -0.049853
# 2  0.029101 -0.046972 -0.005141    ...     0.005620 -0.013260 -0.011183
# 3 -0.035576  0.024496 -0.002917    ...    -0.067429 -0.047952 -0.017362
# 4 -0.065641  0.065562  0.011348    ...    -0.031997 -0.042690 -0.037942
# 5  0.006410 -0.023384  0.004152    ...     0.032905  0.030760  0.022095
# 6  0.062384 -0.006846 -0.015929    ...    -0.026314  0.021832  0.027419
#
#        talk      shot  americans      week      kill   general     cover
# 0  0.069181 -0.023291  -0.002715 -0.015471  0.025373 -0.003936  0.013068
# 1 -0.033911 -0.066114  -0.075909 -0.044708  0.033177 -0.034202 -0.035806
# 2 -0.019148 -0.000112   0.009729 -0.006112 -0.042703  0.006491  0.007853
# 3  0.007054  0.200417   0.020688  0.015760 -0.022786  0.044854  0.025254
# 4 -0.039935 -0.060370   0.060837  0.039951 -0.004617 -0.044956 -0.041523
# 5  0.033368 -0.010867   0.013554 -0.013382  0.002585  0.008055  0.014928
# 6 -0.016609 -0.039663  -0.026184  0.023961  0.008970  0.023693  0.016226
#
# [7 rows x 1000 columns]

# %%
X_train_dense = pd.DataFrame(X_train_dense)
coefs = pd.DataFrame(lr.coef_)
coefs.columns = v.vocabulary_
coefs
dicty = {}
for i in coefs:
    dicty[i] = [sum(abs(coefs[i]))]
dicty
from operator import itemgetter
log_reg_imp = sorted(dicty.items(), key=itemgetter(1), reverse=True)[:50]

# %%
abs(coefs.ix[0]).sort_values(ascending=False)[:50]
# Out:
# reading          0.441399
# actually         0.325474
# says             0.294908
# motif            0.266122
# work             0.232446
# said             0.229379
# sell             0.225263
# entire           0.221987
# paper            0.219228
# likely           0.218573
# tax              0.217304
# form             0.216176
# lost             0.210986
# carry            0.209438
# solution         0.204709
# aren             0.204440
# mother           0.202524
# commercial       0.202110
# hear             0.199639
# bus              0.198943
# user             0.196516
# care             0.193427
# nsa              0.190908
# published        0.190523
# wrong            0.189395
# answer           0.189198
# middle           0.187677
# christianity     0.187378
# result           0.185032
# software         0.183959
# method           0.182434
# people           0.180368
# bits             0.180137
# applications     0.179534
# assume           0.175537
# original         0.173986
# modem            0.173653
# crime            0.171046
# application      0.169788
# water            0.168170
# understanding    0.167723
# local            0.166390
# march            0.166125
# shuttle          0.163196
# false            0.162051
# job              0.162029
# yes              0.161091
# believe          0.160808
# message          0.159216
# plus             0.158067
# Name: 0, dtype: float64

# %%
coefs
# Out:
#         fit    ground     learn      runs     night    person   similar  \
# 0 -0.009369 -0.013885  0.040138 -0.021902  0.121061 -0.061837  0.119830
# 1 -0.027374  0.136841 -0.039278  0.089862 -0.058538  0.079624 -0.065770
# 2 -0.070901 -0.210796 -0.101286  0.035665 -0.104222  0.194693  0.108169
# 3  0.173623 -0.078766 -0.012864 -0.068339  0.000992  0.054437 -0.136064
# 4  0.028261  0.092189 -0.013152 -0.004622 -0.015548 -0.329946  0.009259
# 5  0.021579  0.070118  0.091714 -0.024246  0.012812  0.099902 -0.076929
# 6 -0.115819  0.004299  0.034727 -0.006418  0.043443 -0.036872  0.041504
#
#        room    wonder     teams    ...       allows    market  probably  \
# 0 -0.009055 -0.005138  0.079657    ...     0.132927  0.093400  0.115206
# 1  0.002518  0.129336  0.045453    ...     0.095052  0.014230 -0.086207
# 2  0.075041 -0.142029  0.035111    ...     0.007178 -0.009490 -0.013108
# 3  0.008953  0.129115 -0.043138    ...    -0.106931 -0.122726 -0.016674
# 4 -0.223429  0.072207 -0.067928    ...    -0.114651 -0.128043  0.005035
# 5  0.074567 -0.060128 -0.020087    ...     0.089343  0.040202  0.009289
# 6  0.071405 -0.123362 -0.029069    ...    -0.102918  0.112428 -0.013541
#
#        talk      shot  americans      week      kill   general     cover
# 0  0.074191 -0.041012   0.089361  0.014042  0.033041 -0.024165  0.048476
# 1 -0.145124 -0.204136  -0.106080  0.021931  0.066772 -0.084147 -0.090270
# 2 -0.045928  0.059232   0.074447 -0.024390 -0.149559 -0.008951  0.002395
# 3  0.049251  0.219310   0.041163 -0.088957  0.036934  0.008385  0.027211
# 4 -0.027428  0.014273   0.009890  0.071793  0.094561  0.023949 -0.022881
# 5  0.068515 -0.049581   0.049394 -0.121469 -0.081203  0.044537  0.046349
# 6  0.026523  0.001915  -0.158175  0.127049 -0.000545  0.040392 -0.011279
#
# [7 rows x 1000 columns]

# %%
lr.score(X_scld_test, y_test)
# Out:
# 0.67273701124799146

# %%
print classification_report(y_test, y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.62      0.19      0.29       148
#           1       0.73      0.88      0.80       948
#           2       0.79      0.55      0.65       188
#           3       0.58      0.80      0.67       789
#           4       0.73      0.58      0.65       795
#           5       0.70      0.45      0.54       202
#           6       0.68      0.59      0.64       664
#
# avg / total       0.69      0.68      0.67      3734

# %%
y_pred = lr.predict(X_scld_test)
con = confusion_matrix(y_test, y_pred)
con
# Out:
# array([[ 61,   7,   1,  16,  13,  13,  37],
#        [  6, 745,  30,  58,  81,   6,  22],
#        [  1,  29, 112,  17,  23,   0,   6],
#        [ 20,  50,  14, 558,  80,  14,  53],
#        [ 21,  86,  13,  98, 512,  10,  55],
#        [ 15,   4,   4,   6,  12, 107,  54],
#        [ 38,  16,   3,  82,  69,  39, 417]])

# %%
sel = SelectKBest(f_classif, k=50)
skb_imp = pd.DataFrame(sel.fit_transform(X_scld, y))
mask = sel.get_support()
imp = pd.DataFrame(np.asarray(v.get_feature_names())[sel.get_support()])
imp.columns = ['sel_k']
imp['logreg'] = sorted([i[0] for i in log_reg_imp])
imp
# Out:
#           sel_k          logreg
# 0         block            aren
# 1           btw         article
# 2    california          assume
# 3        called          author
# 4         calls            bike
# 5         chips             bob
# 6        christ             btw
# 7        claims          called
# 8         clear         changes
# 9    completely        children
# 10   conference      commercial
# 11     contains  communications
# 12        cover      discussion
# 13        cross         earlier
# 14      current           early
# 15    currently       functions
# 16          cut            guns
# 17         data            held
# 18         deal        involved
# 19        death          likely
# 20          dec           local
# 21      general            look
# 22       giving            love
# 23         hope            main
# 24      include          middle
# 25     increase          mother
# 26  information           motif
# 27  interesting        new york
# 28    interface            page
# 29         live          places
# 30        lives          policy
# 31         lost            post
# 32          lot           prove
# 33         love         reading
# 34      options             rom
# 35        place         running
# 36      problem            said
# 37     problems             san
# 38      program            says
# 39     programs           sites
# 40       school           space
# 41          sci        standard
# 42       screen         started
# 43      service            stop
# 44     services            tell
# 45       spirit          usenet
# 46         team           users
# 47        turks          values
# 48        woman         various
# 49        write             vga

# %% [markdown]
# #### 3. Create the Truncated Singular Value Decomposition.

# %%
sc = StandardScaler()
trunc = TruncatedSVD(n_components=5)
truncy = pd.DataFrame(trunc.fit_transform(x_train))

# %%
pd.DataFrame(trunc.explained_variance_ratio_)
# Out:
#           0
# 0  0.005845
# 1  0.009688
# 2  0.006977
# 3  0.005988
# 4  0.005818

# %% [markdown]
# #### 4. Setup your k-means clustering

# %%
km = KMeans(n_clusters=7)
km.fit(truncy, y_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
labels = pd.DataFrame(km.labels_)

# %%
thing = pd.concat([pd.DataFrame(y_train), truncy, labels], axis=1)
thing.columns = ['y', 'pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'labels']

# %%
import seaborn as sns
sns.pairplot(thing, hue='labels')

# %%
thing['labels'].value_counts()
# Out:
# 0    2555
# 5    1838
# 6    1365
# 3     777
# 1     498
# 4     310
# 2     237
# Name: labels, dtype: int64

# %%
print classification_report(thing['y'], thing['labels'])
confusion_matrix(thing['y'], thing['labels'])
# Out:
#              precision    recall  f1-score   support
#
#           0       0.05      0.40      0.09       332
#           1       0.00      0.00      0.00      1988
#           2       0.19      0.12      0.15       397
#           3       0.10      0.05      0.06      1600
#           4       0.00      0.00      0.00      1578
#           5       0.06      0.26      0.09       397
#           6       0.01      0.01      0.01      1288
#
# avg / total       0.04      0.05      0.03      7580
# array([[132,   1,   0,   4,  63, 131,   1],
#        [418,   2, 164, 487,   0,  83, 834],
#        [136,  25,  46,  63,   0,  16, 111],
#        [635, 458,  19,  74,   6, 338,  70],
#        [593,   8,   7, 127,   1, 515, 327],
#        [106,   0,   0,   9, 175, 103,   4],
#        [535,   4,   1,  13,  65, 652,  18]])

# %% [markdown]
# #### 5. Fit the vectorizer and SVD

# %%
# look up np.choose

# %% [markdown]
# What are top 50 most useful terms based on article itself? Are those terms similar to the top 50 from step 2?

# %% [markdown]
# Plot the cummulative variace from the terms. x-axis: number of components; y-axis: cummulative variance.
# Based on the plot, decide how many principle components you need.

# %% [markdown]
# #### 7. Fit the kmeans (Question: in this case, do you recommend running K-means without dimension reduction?)

# %% [markdown]
# Print out your centroids. Look at the value for each centroid. Does each centroid represent a news group as expected?

# %% [markdown]
# #### 8. Check the performance of our kmeans

# %% [markdown]
# #### Classification Report

# %% [markdown]
# #### Confusion Matrix. Hint: create a map to translate the label between k-means clustering and the original target (newsgroups_train.target).

# %% [markdown]
# #### Note: Repeat the lab with:
# - varying values of "k"
# - trying a different way to pick starting centroids ('k-means++' is the default method for centroids). For example, pick one point from each newsgroup.
